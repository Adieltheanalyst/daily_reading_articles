# %%
import requests, json,os
from dotenv import load_dotenv
load_dotenv()
import re
import os
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from dotenv import load_dotenv

def fetch_articles():
    api_key=os.getenv("NEWS_API_KEY")
    url="https://newsapi.org/v2/everything"
    params={
        "q":"economy OR inflation OR IPO OR earnings OR opinion",
        "language":"en",
        "page_size":20,
        "apikey":api_key
    }
    res= requests.get(url,params=params)
    return res.json().get("articles",[])

# %%
res.json().get("articles",[])
# Out:
# [{'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': 'UK will be second-fastest-growing G7 economy, IMF predicts',
#   'description': 'The International Monetary Fund (IMF) has upgraded the rate at which the UK economy will grow this year.',
#   'url': 'https://www.bbc.com/news/articles/cn092p27xn0o',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/64e5/live/68968370-a8ef-11f0-92db-77261a15b9d2.jpg',
#   'publishedAt': '2025-10-14T13:00:40Z',
#   'content': 'Faisal IslamBBC Economics Editor\r\nChancellor Rachel Reeves said, despite the IMF\'s upgrade to UK economic growth, "for too many people, our economy feels stuck"\r\nThe UK is forecast to be the second-f… [+4476 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Madison Hoff',
#   'title': 'As the government shutdown drags on, company earnings may give a clue about how the economy is faring',
#   'description': "The government shutdown means key federal data isn't being published. This week's earnings marathon can show the direction of the economy.",
#   'url': 'https://www.businessinsider.com/government-shutdown-economic-data-earnings-calls-2025-10',
#   'urlToImage': 'https://i.insider.com/68e8f6a31c1f80efbec555df?width=1200&format=jpeg',
#   'publishedAt': '2025-10-13T09:20:02Z',
#   'content': 'There will be several earnings announcements this week from companies in the financial sector.FilippoBacci/Getty Images\r\n<ul><li>A wave of earnings announcements this week will give clues about the s… [+3660 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'AJ Dellinger',
#   'title': 'Welcome to the ‘Jobless Growth’ Economy',
#   'description': 'Companies counting on AI are closing the door on entry-level workers.',
#   'url': 'https://gizmodo.com/welcome-to-the-jobless-growth-economy-2000673236',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/09/jobs.jpg',
#   'publishedAt': '2025-10-17T12:30:59Z',
#   'content': 'America is entering an era of “jobless growth,” according to analysts at Goldman Sachs. That’s not ideal for those of us who are job-reliant. It’s especially not great for those who don’t currently h… [+2984 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Sandra Upson',
#   'title': 'How to Build an AI Startup: Go Big, Be Strange, Embrace Probable Doom',
#   'description': 'Thousands of entrepreneurs are trying to rebuild the economy around AI. I set out to see how they’re actually doing it.',
#   'url': 'https://www.wired.com/story/ai-startup-interview-founders/',
#   'urlToImage': 'https://media.wired.com/photos/68fc00a1582abcd215b5b4af/191:100/w_1280,c_limit/WIRED-AI-as_Startup_Blue.jpg',
#   'publishedAt': '2025-10-27T10:00:00Z',
#   'content': 'Earth, its said, is home to more than 10,000 AI startups. Theyre more abundant than cheetahs. They outnumber dawn redwoods. The figure is a guess, of coursestartups come, startups go. But last year, … [+3498 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'AJ Dellinger',
#   'title': 'Is the AI Conveyor Belt of Capital About to Stop?',
#   'description': "Good thing it's only the entire economy propped up by this right now.",
#   'url': 'https://gizmodo.com/is-the-ai-conveyor-belt-of-capital-about-to-stop-2000671017',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/10/openAI_oracle_stargate-1200x675.jpg',
#   'publishedAt': '2025-10-13T19:40:03Z',
#   'content': 'The American economy is little more than a big bet on AI. Morgan Stanley investor Ruchir Sharma recently noted that money poured into AI investments now accounts for about 40% of the United States GD… [+12177 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': 'Nick Mashiter',
#   'title': "'I heard their opinion' - Postecoglou undaunted as fans turn",
#   'description': 'Ange Postecoglou remains defiant despite Nottingham Forest fans turning on the new manager after a sixth game without a win.',
#   'url': 'https://www.bbc.com/sport/football/articles/cd72wenj4vdo',
#   'urlToImage': 'https://ichef.bbci.co.uk/ace/branded_sport/1200/cpsprodpb/a1ff/live/f8854ad0-9fd9-11f0-9dfc-fb769328a6c6.jpg',
#   'publishedAt': '2025-10-02T22:39:34Z',
#   'content': 'Ange Postecoglou remained defiant as Nottingham Forest fans called for him to be sacked after barely three weeks in charge.\r\nA damaging 3-2 Europa League defeat by Midtjylland means Postecoglou is wi… [+3466 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': 'Scott Horsley',
#   'title': 'Government shutdown could delay key economic reports at an especially sensitive time',
#   'description': 'The federal government shutdown, which began overnight, will delay key reports on the U.S. economy, including a monthly snapshot of the job market, which was scheduled for release on Friday.',
#   'url': 'https://www.npr.org/2025/10/01/nx-s1-5558020/government-shutdown-economic-data-jobs-inflation',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/6000x3375+0+313/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F7d%2F97%2F944ee6b741348e61dd922f0eb86f%2Fgettyimages-2233901120.jpg',
#   'publishedAt': '2025-10-01T11:00:00Z',
#   'content': 'A key report on the job market will not be published on Friday, as scheduled, as a result of the government shutdown. That means businesses and policymakers will be left guessing about the strength o… [+2229 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': 'Chancellor says Brexit deal caused long-term damage to economy',
#   'description': "Rachel Reeves made the comments about the 2020 deal at a key meeting of the world's leading finance ministers and central bankers.",
#   'url': 'https://www.bbc.com/news/articles/cy0ypx859x8o',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/102a/live/7b4197c0-ad5f-11f0-98e8-3566ee1f8238.jpg',
#   'publishedAt': '2025-10-20T04:30:35Z',
#   'content': 'Faisal IslamEconomics editor\r\nRachel Reeves chose to stress the long-term damage done to the UK economy by the 2020 Brexit deal, in her remarks at a key international economic committee at the Intern… [+2446 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Ece Yildirim',
#   'title': 'Dyson Isn’t Doing So Great',
#   'description': "The company's annual profits were nearly slashed in half despite record sales.",
#   'url': 'https://gizmodo.com/dyson-isnt-doing-so-great-2000665674',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/09/shutterstock_2477406313-1200x675.jpg',
#   'publishedAt': '2025-09-30T19:25:18Z',
#   'content': 'Consumer electronics giant Dyson’s profits were nearly halved in 2024, despite selling more products this year than they have ever before.\r\nThe company’s pre-tax profit for 2024 fell to £561 million … [+2872 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Nilay Patel',
#   'title': 'Zocdoc CEO: ‘Dr. Google is going to be replaced by Dr. AI’',
#   'description': 'Today’s Decoder episode is a special one: I’m talking to Zocdoc CEO Oliver Kharraz, and we chatted live onstage at the TechFutures conference here in New York City.\xa0 You’re almost certainly familiar with Zocdoc — it’s a platform that helps people find and boo…',
#   'url': 'https://www.theverge.com/podcast/801767/zocdoc-ceo-oliver-kharraz-ai-medical-healthcare-doctors',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/10/DCD-Oliver-Kharraz.png?quality=90&strip=all&crop=0%2C10.711631919237%2C100%2C78.576736161526&w=1200',
#   'publishedAt': '2025-10-20T13:59:34Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nOliver Kharraz on competition, healthcare, and where AI really belongs in medicine.\r\nby\r\nNilay PatelClose\r\nNilay Patel\r\nPosts from this author will be added to y… [+60466 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew J. Hawkins',
#   'title': 'GM to end production of electric Chevy Brightdrop vans',
#   'description': 'General Motors will end production of its Chevy Brightdrop electric vans at its factory in Ingersol, Ontario, the company said during its third quarter earnings call Tuesday. The decision was made as slow demand in the electric van market led to hundreds of B…',
#   'url': 'https://www.theverge.com/news/803385/gm-chevy-brightdrop-ev-end-production-van-canada',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/10/gettyimages-2225114191.jpg?quality=90&strip=all&crop=0%2C10.700234488601%2C100%2C78.599531022798&w=1200',
#   'publishedAt': '2025-10-21T15:11:39Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nDemand in the electric van market has slowed considerably since the expiration of the EV tax credit.\r\nDemand in the electric van market has slowed considerably s… [+3250 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew J. Hawkins',
#   'title': 'Elon Musk says he needs $1 trillion to control Tesla’s ‘robot army’',
#   'description': 'Well, that’s not very subtle. In an earnings call last night, Tesla CEO Elon Musk said he needs more control over Tesla, as well as a pay package that could be worth nearly $1 trillion, in exchange for building a “robot army.” Otherwise, he could get ousted a…',
#   'url': 'https://www.theverge.com/transportation/805247/tesla-q3-earnings-elon-musk-robot-army-pay-package',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/04/STK171_VRG_Illo_16_Normand_ElonMusk_16.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-10-23T15:57:50Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nTesla shareholders will decide whether Musk deserves his money, and his robot army, at an upcoming meeting.\r\nTesla shareholders will decide whether Musk deserves… [+6398 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': 'Scott Simon',
#   'title': 'Opinion: Susan Stamberg gave NPR its voice',
#   'description': 'NPR has lost a singular, distinctive radio journalist: Susan Stamberg, who died Thursday. She was the first woman to host a national news broadcast and set the tone, pace, and scope of the network.',
#   'url': 'https://www.npr.org/2025/10/18/nx-s1-5572394/opinion-susan-stamberg-gave-npr-its-voice',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/3000x1688+0+183/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F73%2F52%2F415d85e548c0abd1786238be17bd%2Fap25289841640737.jpg',
#   'publishedAt': '2025-10-18T12:00:00Z',
#   'content': 'We are here and I mean on the air with you today because of Susan Stamberg. There are of course others who helped turn the idea of National Public Radio into a distinctive sound. But a little over 50… [+2127 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': 'Tax rises could push food prices higher, warn supermarkets',
#   'description': "The bosses of the UK's largest supermarkets warn the chancellor against imposing higher taxes on the industry.",
#   'url': 'https://www.bbc.com/news/articles/c620gy43pe4o',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/9f69/live/0c5cf5a0-b0ea-11f0-a072-177e9709dffa.jpg',
#   'publishedAt': '2025-10-25T23:00:58Z',
#   'content': "Michael RaceBusiness reporter\r\nThe bosses of Britain's biggest supermarkets have warned food prices could rise even further if higher taxes are imposed on the sector.\r\nGrocers including Tesco, Asda, … [+5590 chars]"},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': 'Maria Aspan',
#   'title': 'Why gold is having its best year since 1979',
#   'description': "The price of gold hit $4,000 per ounce for the first time ever. It's a bad sign for the U.S. economy",
#   'url': 'https://www.npr.org/2025/10/08/nx-s1-5566666/gold-hits-record-best-year-1979',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/4476x2518+0+233/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fe3%2F99%2F3dc5f53f4e96bf5ded2440daac5c%2Fgettyimages-2212003936.jpg',
#   'publishedAt': '2025-10-08T16:41:10Z',
#   'content': 'Gold has broken yet another record this week, illustrating just how anxious investors are about the health of the U.S. economy.\r\nThis week, the price of gold hit $4,000 per ounce for the first time e… [+3388 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Rebecca Torrence',
#   'title': 'Healthcare company Ensemble Health has tapped JPMorgan as it eyes a $13 billion sale or IPO in 2026',
#   'description': 'The healthcare revenue management company wants to sell or IPO at $13 billion, and will go to market early next year, sources told Business Insider.',
#   'url': 'https://www.businessinsider.com/ensemble-health-hires-jpmorgan-goldman-sachs-for-sale-ipo-2025-10',
#   'urlToImage': 'https://i.insider.com/68fa335f599d46a4ccc0b40a?width=1200&format=jpeg',
#   'publishedAt': '2025-10-23T17:14:12Z',
#   'content': 'Mike Kemp/In Pictures via Getty Images\r\n<ul><li>Ensemble Health has hired JPMorgan and Goldman Sachs for a sale or IPO early next year, BI learned.</li><li>The PE-backed healthcare company is aiming … [+4497 chars]'},
#  {'source': {'id': 'abc-news', 'name': 'ABC News'},
#   'author': 'Max Zahn',
#   'title': 'Inflation climbs to highest level since January',
#   'description': 'A recent uptick in prices has coincided with a sharp slowdown of hiring.',
#   'url': 'https://abcnews.go.com/Business/inflation-expected-reach-highest-level-year/story?id=126752284',
#   'urlToImage': 'https://i.abcnewsfe.com/a/001f6bf8-7a29-44eb-9b4d-e5bdd9394eaf/grocery-prices-2-gty-gmh-251023_1761250421545_hpMain_16x9.jpg?w=1600',
#   'publishedAt': '2025-10-24T12:50:19Z',
#   'content': 'Consumer prices rose 3% in September compared to a year ago, extending a monthslong uptick that has sent inflation to its highest level since January, government data on Friday showed. The reading ca… [+2700 chars]'},
#  {'source': {'id': 'buzzfeed', 'name': 'Buzzfeed'},
#   'author': 'Alexa Lisitza',
#   'title': "I'm Very Curious About How MAGA Will Try To Explain Away This Look At How Donald Trump's Economy Is Going...",
#   'description': "I'm keeping track of Trump's economy right here. Every month. Enjoy!View Entire Post ›",
#   'url': 'https://www.buzzfeed.com/alexalisitza/tracking-trumps-economy-august',
#   'urlToImage': 'https://img.buzzfeed.com/buzzfeed-static/static/2025-09/25/20/thumb/vzKe_ddzk.jpg?crop=2997:1569;0,0%26downsize=1250:*',
#   'publishedAt': '2025-10-01T17:12:29Z',
#   'content': "Wowwwww, would you look at that! Joe Biden's inflation this, Joe Biden's inflation that, but inflation just hit the same percentage under Trump that Biden experienced during his last month in office:… [+272 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Madison Hoff',
#   'title': "The government shutdown is putting Friday's jobs report in jeopardy",
#   'description': 'The government shutdown means there could be no jobs report this Friday unless things are resolved before then.',
#   'url': 'https://www.businessinsider.com/government-shutdown-jobs-report-bls-economic-data-job-seekers-fed-2025-10',
#   'urlToImage': 'https://i.insider.com/68dc11e15dbc4fd10da9ddc2?width=1200&format=jpeg',
#   'publishedAt': '2025-10-01T04:01:05Z',
#   'content': "If the government remains shut down on Friday, it means the Bureau of Labor Statistics' monthly jobs report won't be published.Joe Raedle/Getty Images\r\n<ul><li>The US government has shut down, and th… [+3714 chars]"},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': 'Will my uni fees rise next year? What is a V-level? Your questions answered',
#   'description': 'The DfE has announced it will raise tuition fees every year, and will bring in new V-levels after GCSEs.',
#   'url': 'https://www.bbc.com/news/articles/crred9ljqz7o',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/eaa3/live/d80a9160-ae85-11f0-b0ec-2949909959e5.jpg',
#   'publishedAt': '2025-10-21T17:00:26Z',
#   'content': "Hayley ClarkeEducation reporter\r\nWhat questions do you have about university tuition fees and V-levels? \r\nThe government has published its new white paper, and there's big news in it for students goi… [+6770 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'insider@insider.com (Insider Inc.)',
#   'title': 'Experts share strategies for a successful IPO',
#   'description': 'Industry professionals outline best practices for IPO success, focusing on preparation, regulatory compliance, and employee benefits at the Business Insider and Fidelity-hosted discussion.',
#   'url': 'https://www.businessinsider.com/sc/preparing-for-ipo-experts-reveal-strategies-to-meet-investor-expectations-and-stay-ready',
#   'urlToImage': 'https://i.insider.com/68e5731d1c1f80efbec51ca1?width=1200&format=jpeg',
#   'publishedAt': '2025-10-09T17:20:14Z',
#   'content': 'Fidelity Investments is a sponsor of "Beyond the Bell: Navigating The Path to Public." This article was specially created for Fidelity Investments.\r\nAs companies prepare for an initial public offerin… [+3986 chars]'},
#  {'source': {'id': 'abc-news', 'name': 'ABC News'},
#   'author': 'Max Zahn',
#   'title': 'Could the government shutdown tip the US into a recession? Experts weigh in',
#   'description': 'The U.S. economy remains largely unscathed but pressure could mount.',
#   'url': 'https://abcnews.go.com/Business/government-shutdown-tip-us-recession-experts-weigh/story?id=126752206',
#   'urlToImage': 'https://i.abcnewsfe.com/a/f1d74187-0673-4385-b499-08089f8792a4/capitol-building-gty-jef-251023_1761243646013_hpMain_16x9.jpg?w=1600',
#   'publishedAt': '2025-10-24T09:19:29Z',
#   'content': 'The U.S. economy remains largely unscathed by the government shutdown, but the nation could risk economic peril if the impasse deepens into a long-term standoff, some economists told ABC News.\r\nRough… [+4352 chars]'},
#  {'source': {'id': 'abc-news', 'name': 'ABC News'},
#   'author': 'Max Zahn',
#   'title': 'Would a government shutdown hurt the economy? Experts explain',
#   'description': 'The federal government is hurtling toward a possible shutdown Tuesday night.',
#   'url': 'https://abcnews.go.com/Business/government-shutdown-hurt-economy-experts-explain/story?id=126038221',
#   'urlToImage': 'https://i.abcnewsfe.com/a/1d3819ec-fa25-4eba-9564-f00394ec028e/capitol-2-gty-gmh-250929_1759169305756_hpMain_16x9.jpg?w=1600',
#   'publishedAt': '2025-09-30T09:13:48Z',
#   'content': "The federal government is hurtling toward a possible shutdown at a delicate moment for the nation's economy, as a hiring slowdown stokes recession fears and inflation proves difficult to fully contai… [+5722 chars]"},
#  {'source': {'id': 'the-hill', 'name': 'The Hill'},
#   'author': 'Dov S. Zakheim, opinion contributor',
#   'title': 'Opinion - It’s been a bad year for Iran — Trump should keep pressing to make it worse',
#   'description': 'In December 2004, Jordan’s King Abdullah first warned the world of the emergence of a Sh’ia crescent that could destabilize the region’s Sunni states...',
#   'url': 'https://thehill.com/opinion/national-security/5559031-its-been-a-bad-year-for-iran-trump-should-keep-pressing-to-make-it-worse/',
#   'urlToImage': 'https://media.zenfs.com/en/the_hill_articles_341/bd6c54eb54250b225ee02fb7f1811a94',
#   'publishedAt': '2025-10-17T13:30:00Z',
#   'content': 'In December 2004, Jordans King Abdullah first warned the world of the emergence of a Shia crescent that could destabilize the regions Sunni states. Initially discounted by numerous analysts, his obse… [+5890 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'katherineli@insider.com (Katherine Li,Lloyd Lee)',
#   'title': "5 big takeaways from Tesla's Q3 earnings call — including fiery words from Musk over $1 trillion pay package",
#   'description': "During the Q3 earnings call, the EV maker discussed CEO Elon Musk's $1 trillion pay package, set a timeline for Tesla Robotaxi, and teased Optimus V3.",
#   'url': 'https://www.businessinsider.com/5-big-takeaways-from-teslas-q3-earnings-call-2025-10',
#   'urlToImage': 'https://i.insider.com/68f98bd0c007ca8c27377797?width=1200&format=jpeg',
#   'publishedAt': '2025-10-23T02:36:09Z',
#   'content': "Tesla reported a mixed bag of results in its Q3 earnings.\r\nProfits and adjusted earnings per share both missed Wall Street expectations. Tesla's third-quarter revenue,however, reached an all-time hig… [+5086 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Madison Hoff',
#   'title': 'Inflation continued to accelerate in September',
#   'description': 'The Bureau of Labor Statistics published the new inflation report during the government shutdown, which has affected some of its operations.',
#   'url': 'https://www.businessinsider.com/inflation-september-cpi-consumer-price-index-federal-reserve-interest-rates-2025-10',
#   'urlToImage': 'https://i.insider.com/68fa45c0c007ca8c27377ed5?width=1200&format=jpeg',
#   'publishedAt': '2025-10-24T12:34:05Z',
#   'content': 'The Bureau of Labor Statistics published inflation data on Friday.Jeffrey Greenberg/Universal Images Group via Getty Images\r\n<ul><li>Year-over-year inflation rose to 3.0% in September from 2.9%, just… [+2643 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Mike Pearl',
#   'title': 'Netflix’s Stock Drops on Lackluster Earnings, but Its AI Implementation Is Going Way Up',
#   'description': 'With all the AI talk, it feels like 2023 again at Netflix.',
#   'url': 'https://gizmodo.com/netflixs-ai-implementation-is-going-way-up-2000675360',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/10/netflix-building-1200x675.jpg',
#   'publishedAt': '2025-10-22T04:13:18Z',
#   'content': 'Netflix reported its quarterly earnings on Tuesday, and revenue was $11.51 billionslightly below Bloombergs forecast of $11.52 billion. Earnings per share were $5.87, below an estimate of $6.94. (All… [+3577 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Madison Hoff',
#   'title': 'I run coffee shops and bars in Chicago. Tariffs and uncertainty forced me to freeze hiring, cut jobs, and raise prices.',
#   'description': "The owner of Chicago's Heritage Hospitality Group said tariffs and inflation are driving up costs, forcing him to raise prices and cut staff.",
#   'url': 'https://www.businessinsider.com/tariffs-inflation-economy-chicago-small-business-2025-10',
#   'urlToImage': 'https://i.insider.com/68f28ea4cc993f9955d06cfe?width=1200&format=jpeg',
#   'publishedAt': '2025-10-19T08:46:01Z',
#   'content': 'Michael Salvatore, who runs coffee shops and bars, has made some changes and is figuring out how else tariffs will affect business operations.Melissa Salvatore, Field Creatives\r\n<ul><li>Michael Salva… [+7724 chars]'},
#  {'source': {'id': 'the-hill', 'name': 'The Hill'},
#   'author': 'Rep. Raja Krishnamoorthi\xa0(D-Ill.), opinion contributor',
#   'title': 'Opinion - Beijing summit raises the risk of armed conflict',
#   'description': "Xi Jinping is using his influence to align the world's most powerful dictators against America, while the US is weakening its institutions and alienating its...",
#   'url': 'https://thehill.com/opinion/national-security/5529952-trump-xi-phone-call-progress/',
#   'urlToImage': 'https://media.zenfs.com/en/the_hill_articles_341/9c435f71a3f3a715b575af64643c614c',
#   'publishedAt': '2025-10-01T13:30:00Z',
#   'content': 'President Trump and Chinese leader Xi Jinping concluded their long-awaited phone call on Sept. 19. According to Trump, the U.S. and China made unspecified progress on issues ranging from tariffs to f… [+4950 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Swati Bhat',
#   'title': 'RBI expected to hold policy rate, but surprise cut possible',
#   'description': 'MUMBAI (Reuters) -The Reserve Bank of India is widely expected to hold its key policy rate at 5.50% on Wednesday, though some economists say a surprise cut...',
#   'url': 'https://sg.finance.yahoo.com/news/rbi-expected-hold-policy-rate-013259089.html',
#   'urlToImage': 'https://media.zenfs.com/en/reuters.com/f301458605b080ad8f587c44f098c703',
#   'publishedAt': '2025-09-29T01:32:59Z',
#   'content': 'By Swati Bhat\r\nMUMBAI (Reuters) -The Reserve Bank of India is widely expected to hold its key policy rate at 5.50% on Wednesday, though some economists say a surprise cut cannot be ruled out as it we… [+2519 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Paul Ford',
#   'title': 'The Argument for Letting AI Burn It All Down',
#   'description': 'When the AI bubble bursts, the nerds will do their best work.',
#   'url': 'https://www.wired.com/story/ai-normal-after-ai-plateaus/',
#   'urlToImage': 'https://media.wired.com/photos/68e83fefb02e55ff56b21b54/191:100/w_1280,c_limit/WIRED-AI-as_Normal_Blue_2.jpg',
#   'publishedAt': '2025-10-27T10:00:00Z',
#   'content': 'Suddenly, and not long ago, our dearest tech industry leaders began to suggest caution. Sam Altman said that AI is in a bubble for sure, albeit one formed around a kernel of truth. Mark Zuckerberg sa… [+3018 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Erica Sweeney',
#   'title': 'Experts share strategies for a successful IPO',
#   'description': 'Industry professionals outline best practices for IPO success, focusing on preparation, regulatory compliance, and employee benefits at the Business Insider and Fidelity-hosted discussion.',
#   'url': 'https://www.businessinsider.com/experts-offer-essential-strategies-for-ipo-success-2025-10',
#   'urlToImage': 'https://i.insider.com/68e5731d1c1f80efbec51ca1?width=1200&format=jpeg',
#   'publishedAt': '2025-10-09T19:15:58Z',
#   'content': 'Event speakers included Atil, Cervino, Buck, and Villar Jr. (left to right)Business Insider\r\n<ul><li>Companies face challenges like shifting investor expectations and regulations when preparing for I… [+5705 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': "How Milei's 'Thatcherite' economics divided his nation - but won over Trump",
#   'description': "Ahead of Milei's visit to the White House - amid protests and anger on the streets back at home - Ione Wells unravels the paradox that Argentina's president has created",
#   'url': 'https://www.bbc.com/news/articles/c9865l8540eo',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/91a6/live/955aae40-a8f4-11f0-b741-177e3e2c2fc7.png',
#   'publishedAt': '2025-10-14T12:26:40Z',
#   'content': 'Buenos Aires, September 2023. Hundreds of people crowded around to wave flags and film on their phones. The man with unruly hair and sideburns in the centre of them, clad in a black leather jacket, h… [+12138 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Angela Watercutter',
#   'title': 'The Long History of Frogs as Protest Symbols',
#   'description': "Inflatable frog costumes are selling out following the weekend's “No Kings” protests and to counter Trump’s demonization of US cities more broadly.",
#   'url': 'https://www.wired.com/story/the-long-history-of-frogs-as-protest-symbols/',
#   'urlToImage': 'https://media.wired.com/photos/68f6c7e46c32e97a4e58a48a/191:100/w_1280,c_limit/History-of-Frogs-as-Protest-Avatars-Culture-2239338875.jpg',
#   'publishedAt': '2025-10-21T17:07:06Z',
#   'content': 'Think of it like Wheres Waldo? for the anti-Trump movement: Last Saturday, as some 7 million people filled American cities for the latest No Kings protest, many of them showed up wearing inflatable f… [+2955 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Alex Morrell,Alex Nicoll,Alice Tecotzky,Bradley Saacks,Daniel Geiger,Emmalyse Brownstein,Michelle Abrego,Rebecca Torrence,Reed Alexander',
#   'title': "Business Insider's 2025 Rising Stars of Wall Street",
#   'description': "From financing the future of technology to advising on the IPO comeback, here's why these young finance leaders are the ones to watch in 2025.",
#   'url': 'https://www.businessinsider.com/wall-street-rising-stars-finance-leaders-2025',
#   'urlToImage': 'https://i.insider.com/68deb55dcc993f9955cf66e9?width=1200&format=jpeg',
#   'publishedAt': '2025-10-06T09:25:01Z',
#   'content': "They're still in the early innings of their careers, but these dealmakers and investors are already setting the agenda for the next era of finance.\r\nEach year, Business Insider spotlights up-and-comi… [+53867 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Eleanor Pringle',
#   'title': 'America’s economy is on a ‘sugar high’ warns Ken Griffin, and investors retreating to gold is one sign of a comedown',
#   'description': 'Ken Griffin said investors want to make the most of the rally in American equities but are hedging their spoils out of U.S. sovereign risk.',
#   'url': 'https://finance.yahoo.com/news/america-economy-sugar-high-warns-103054042.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/XvL3C0dAHnw5KtzJtutsLQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/fortune_175/1af12dfe28c4cdcb5982d4dea9e0fc25',
#   'publishedAt': '2025-10-07T10:30:54Z',
#   'content': '<ul><li>Citadel founder and CEO Ken Griffin cautioned that Americas market rally is being propped up by policies better suited to a recession than a growing economy. Speaking in New York, he said fis… [+4239 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': 'Lenny Henry calls for reparations for black British people',
#   'description': "The comedian's new book supports the case for the UK to give £18 trillion in compensatory payments.",
#   'url': 'https://www.bbc.com/news/articles/c5yqn2x490zo',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/70f4/live/4a71ec30-a459-11f0-9060-338e82e0aff9.jpg',
#   'publishedAt': '2025-10-08T16:10:56Z',
#   'content': 'Paul GlynnCulture reporter\r\nSir Lenny Henry has called for the payment of slavery reparations to all black British people.\r\nWriting in a new book titled The Big Payback, the comedian supports the cas… [+2527 chars]'},
#  {'source': {'id': 'abc-news', 'name': 'ABC News'},
#   'author': 'Max Zahn',
#   'title': 'Government shutdown halts data, stokes risk as economy wobbles, experts say',
#   'description': 'Federal agencies said they would not release some key data during the shutdown.',
#   'url': 'https://abcnews.go.com/Business/government-shutdown-halts-data-stokes-risk-economy-wobbles/story?id=126259604',
#   'urlToImage': 'https://i.abcnewsfe.com/a/f057ffec-bdc4-45ad-960e-9faf7d2eb4ab/dept-labor-1-rt-gmh-251006_1759767936640_hpMain_16x9.jpg?w=1600',
#   'publishedAt': '2025-10-06T17:44:02Z',
#   'content': 'The government shutdown halted the release of key economic data, choking off the flow of information as some experts warn the economy may be slipping toward a recession, some economists told ABC News… [+4310 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'EditorDavid',
#   'title': "'The AI Revolution's Next Casualty Could Be the Gig Economy'",
#   'description': '"The gig economy is facing a reckoning," argues Business Insider\'s BI Today newsletter."\n\n\n\n\nTwo stories this past week caught my eye. Uber unveiled a new way for its drivers to earn money. No, not by giving rides, but by helping train the ride-sharing compan…',
#   'url': 'https://slashdot.org/story/25/10/20/0616223/the-ai-revolutions-next-casualty-could-be-the-gig-economy',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/ai_64.png',
#   'publishedAt': '2025-10-20T07:34:00Z',
#   'content': "Two stories this past week caught my eye. Uber unveiled a new way for its drivers to earn money. No, not by giving rides, but by helping train the ride-sharing company's AI models instead. On the sam… [+886 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Steve Russolillo',
#   'title': "The AI revolution's next casualty could be the gig economy",
#   'description': "In this Sunday edition of Business Insider Today, we're talking about how AI is shaking up gig work and what it means for drivers and customers.",
#   'url': 'https://www.businessinsider.com/bi-today-sunday-newsletter-ai-gig-economy-2025-10',
#   'urlToImage': 'https://i.insider.com/68f2a1e9cc993f9955d07008?width=1200&format=jpeg',
#   'publishedAt': '2025-10-19T10:45:01Z',
#   'content': "Nam Y. Huh/AP\r\n<ul><li>This post originally appeared in the BI Today newsletter.</li><li>You can sign up for Business Insider's daily newsletter here.</li></ul>Welcome back to our Sunday edition, whe… [+6407 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Nick Lichtenberg',
#   'title': 'Top analyst still thinks we’re on the cusp of a new boom for the economy, but investors aren’t with him: ‘Markets remain choppy’',
#   'description': 'Morgan Stanley’s Mike Wilson says he needs to see more before giving the “all-clear” on chances of a further near-term correction.',
#   'url': 'https://finance.yahoo.com/news/top-analyst-still-thinks-cusp-171302613.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/B.QZ7qrmUo_VIcdCp8LLlA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/fortune_175/debb6191866cd9d288b99979835fff20',
#   'publishedAt': '2025-10-20T17:13:02Z',
#   'content': 'Morgan Stanley chief equity analyst Mike Wilson has been saying for years the U.S. was in a rolling recession when economists were seeing nothing but GDP growth. Since April, hes been declaring a rol… [+5348 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Alistair Barr,Andy Kiersz',
#   'title': "Elon Musk promised a $25,000 EV in 2020. Including inflation, we're getting closer, but are we there yet?",
#   'description': "Inflation soared during the COVID-19 pandemic. Was that enough to make Musk's $25,000 EV prediction true? We crunched the numbers.",
#   'url': 'https://www.businessinsider.com/elon-musk-promised-25-000-ev-2020-including-inflation-tesla-2025-10',
#   'urlToImage': 'https://i.insider.com/68e5712a5dbc4fd10daa5f67?width=1200&format=jpeg',
#   'publishedAt': '2025-10-07T21:13:49Z',
#   'content': 'Tesla CEO Elon MuskGonzalo Fuentes/REUTERS\r\n<ul><li>In 2020, Elon Musk predicted Tesla would make a $25,000 electric vehicle.</li><li>Inflation soared between then and now, partly due to the pandemic… [+2270 chars]'},
#  {'source': {'id': 'the-hill', 'name': 'The Hill'},
#   'author': 'Jonathan Russo, opinion contributor',
#   'title': 'Opinion - Crypto world, buckle up for the rug-pull of all time',
#   'description': 'The crypto market is ripe for a rug pull, with insiders profiting from the inflated valuations of meme coins, crypto treasury stocks, and other scams...',
#   'url': 'https://thehill.com/opinion/finance/5548075-crypto-rug-pull-warning/',
#   'urlToImage': 'https://media.zenfs.com/en/the_hill_articles_341/62f3b7d105b304b9ac3b4fe072d15ab1',
#   'publishedAt': '2025-10-10T16:00:00Z',
#   'content': 'I have, like so many others, been wrong about Bitcoin and crypto. But timing is not destination, and I believe one day there will be a rug-pull that will wipe trillions off the face of the crypto ear… [+4766 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': 'Scott Simon',
#   'title': 'Opinion: Jane Goodall helped humans understand their place in the world',
#   'description': "Jane Goodall, the influential primatologist and conservationist, died this week at the age of 91. NPR's Scott Simon reflects on her legacy and love for chimpanzees.",
#   'url': 'https://www.npr.org/2025/10/04/nx-s1-5554848/opinion-jane-goodall-helped-humans-understand-their-place-in-the-world',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/1420x799+0+601/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F9b%2F06%2F98ff8c254bd09bd92de73c7a291c%2Fap25129843645450.jpg',
#   'publishedAt': '2025-10-04T12:00:00Z',
#   'content': 'Outside the Field Museum in Chicago, a bronze sculpture by artist Marla Friedman captures a moment a friendship was made.\r\nIt\'s called "The Red Palm Nut." A young woman sits barefoot on the ground, r… [+2088 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': 'Scott Simon',
#   'title': "Opinion: 'The Shipping Forecast' reminds us of the power of the human voice",
#   'description': 'For a century, the BBC has broadcast the weather report for the seas around the UK. "The Shipping Forecast" has informed and lulled generations who tune in to hear it.',
#   'url': 'https://www.npr.org/2025/10/11/nx-s1-5561083/opinion-the-shipping-forecast-reminds-us-of-the-power-of-the-human-voice',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/5616x3159+0+293/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F65%2Fe4%2F418adbc746a38bedf98a21271f71%2Fap120415022447.jpg',
#   'publishedAt': '2025-10-11T11:51:38Z',
#   'content': '"The Shipping Forecast," presented twice on weekdays on the BBC and thrice on weekends, is 100-years-old this week. \r\nIt broadcasts weather forecasts for the seas that surround the British Isles.\r\nYo… [+1767 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': 'Scott Simon',
#   'title': 'Opinion: Ask your doctor if the World Series is right for you...',
#   'description': 'Prescription drug ads were once banned on broadcasts. But companies argued that infringed on free speech, and the drugs could help people. The FDA now permits pharmaceutical ads.',
#   'url': 'https://www.npr.org/2025/10/25/nx-s1-5578898/opinion-ask-your-doctor-if-the-world-series-is-right-for-you',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/6823x3838+0+113/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2Fab%2F88%2F75dbf202419991759f6f452db548%2Fgettyimages-2192532180.jpg',
#   'publishedAt': '2025-10-25T12:00:00Z',
#   'content': "My family and I have been watching post-season baseball, and I think I have to lie down.\r\nWe've seen so many ads for drugs prescribed to treat plaque psoriasis, Crohn's disease, and ulcerative coliti… [+2027 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Allie Kelly,Madison Hoff',
#   'title': 'The Fed is expected to cut rates this week — even while the government is shut down',
#   'description': "The government shutdown means the latest job numbers haven't been released, but the Fed is still likely to cut.",
#   'url': 'https://www.businessinsider.com/what-likely-october-rate-cut-means-for-your-wallet-2025-10',
#   'urlToImage': 'https://i.insider.com/68ffa69ec007ca8c2737b0aa?width=1200&format=jpeg',
#   'publishedAt': '2025-10-28T08:02:01Z',
#   'content': 'The Fed will likely cut interest rates this month.Chip Somodevilla/Getty Images\r\n<ul><li>The Fed is expected to cut interest rates in its October meeting.</li><li>The government shutdown means jobs d… [+4625 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Allaire Conte',
#   'title': 'The IRS Announces New Tax Brackets and Deductions for 2026—and First-Time Buyers Stand To Benefit',
#   'description': 'The IRS has raised 2026 tax brackets to account for inflation, boosting take-home pay for millions. Here’s what it means for first-timers.',
#   'url': 'https://finance.yahoo.com/news/irs-adjusting-tax-brackets-2026-030200025.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/lrUmuho_chDFqKbNSypqHA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/realtor_com_468/a37110c839a40371546b27f0777a72d0',
#   'publishedAt': '2025-10-09T17:19:00Z',
#   'content': 'As summer fades, the housing market is shifting tooand this time, the momentum may be tilting toward buyers. For the first time in years, conditions are aligning to give first-time homebuyers a bette… [+6901 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Ashley Lutz',
#   'title': 'GoFundMe CEO says the economy is so bad that more of his customers are crowdfunding just to pay for their groceries',
#   'description': 'GoFundMe’s CEO says more Americans are crowdfunding everyday essentials like groceries as high costs and strained household finances persist.',
#   'url': 'https://finance.yahoo.com/news/gofundme-ceo-says-economy-bad-182843671.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/0XWQVDFV3tJUXxDK3cNHXA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MTE-/https://media.zenfs.com/en/fortune_175/8b77f1a14084a1ebefd83278630e6bad',
#   'publishedAt': '2025-10-13T18:28:43Z',
#   'content': 'GoFundMes CEO just said the quiet part out loud: in this economy, more Americans are crowdfunding groceries to get by.\r\nThe head of GoFundMe, Tim Cadogan, told Yahoo! Finance the economy is so challe… [+4650 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': 'British parts found in Russian drones, Zelensky says',
#   'description': 'The Ukrainian leader says British-made microcomputers were used in weapons launched at Ukraine this weekend.',
#   'url': 'https://www.bbc.com/news/articles/cg5e9zlpz6eo',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/78e2/live/70b38bb0-a2c4-11f0-8b38-691926760cd4.jpg',
#   'publishedAt': '2025-10-06T18:03:55Z',
#   'content': "Danai Nesta KupembaBBC News \r\nBritish microcomputers were among more than 100,000 foreign-made parts contained in Russian missiles and drones used in Sunday's deadly strikes on Ukraine, Volodymyr Zel… [+2434 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Reed Alexander,Alex Nicoll',
#   'title': 'Goldman Sachs, JPMorgan, and Citi surged past expectations as Wall Street bankers get busy again',
#   'description': 'Goldman Sachs, JPMorgan, and Citi all posted strong earnings returns, signaling a return of dealmaking after years of muted activity.',
#   'url': 'https://www.businessinsider.com/dealmaking-rebound-goldman-jpmorgan-citi-exceed-expectations-q3-earnings-stock-2025-10',
#   'urlToImage': 'https://i.insider.com/68ee90f95dbc4fd10daad54a?width=1200&format=jpeg',
#   'publishedAt': '2025-10-14T18:09:25Z',
#   'content': "Workers in downtown ManhattanMomo Takahashi/BI\r\n<ul><li>Big banks posted strong earnings results as dealmaking returns to Wall Street.</li><li>Goldman's advisory revenue jumped 60% to $1.4 billion fr… [+4416 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Zacks Equity Research',
#   'title': 'Why Investors Need to Take Advantage of These 2 Medical Stocks Now',
#   'description': 'Finding stocks expected to beat quarterly earnings estimates becomes an easier task with our Zacks Earnings ESP.',
#   'url': 'https://finance.yahoo.com/news/why-investors-advantage-2-medical-130004846.html',
#   'urlToImage': 'https://media.zenfs.com/en/zacks.com/8442d24e11d454aa89061259a9714d43',
#   'publishedAt': '2025-10-15T13:00:04Z',
#   'content': "Earnings are arguably the most important single number on a company's quarterly financial report. Wall Street clearly dives into all of the other metrics and management's input, but the EPS figure he… [+2319 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Anneta Konstantinides,Joey Hadden',
#   'title': 'We flew basic economy with Delta and American Airlines. Both were better than expected, but one key difference surprised us.',
#   'description': "We took basic economy flights on Delta Air Lines and American Airlines. Here's how they compared, from the seats and snacks to the entertainment.",
#   'url': 'https://www.businessinsider.com/basic-economy-delta-vs-american-airlines-review-2025-10',
#   'urlToImage': 'https://i.insider.com/68e428541c1f80efbec505b6?width=1200&format=jpeg',
#   'publishedAt': '2025-10-23T11:02:01Z',
#   'content': 'We compared basic economy on American Airlines and Delta.Joey Hadden/Business Insider, Anneta Konstantinides/Business Insider\r\n<ul><li>One of our travel reporters flew basic economy from LA to NYC on… [+7631 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Lauren Edmonds',
#   'title': 'Ulta Beauty CEO says Gen Alpha prefers to shop IRL',
#   'description': 'Gen Alpha, born between 2010 and 2024, are the youngest shoppers driving the global economy. Ulta Beauty says they prefer IRL experiences.',
#   'url': 'https://www.businessinsider.com/ulta-beauty-gen-alpha-prefers-in-store-shopping-korean-beauty-2025-10',
#   'urlToImage': 'https://i.insider.com/68efc8a71c1f80efbec5a22f?width=1200&format=jpeg',
#   'publishedAt': '2025-10-15T18:41:45Z',
#   'content': 'Gen Alpha shoppers are seeking IRL experiences.Fly View Productions/Getty Images\r\n<ul><li>Ulta CEO Kecia Steelman said Gen Alpha shoppers want in-store experiences.</li><li>Gen Alpha shoppers are the… [+3389 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': 'Scott Horsley',
#   'title': "Trump's controversial nominee drops bid to head vital data-gathering agency",
#   'description': "Trump's pick to lead the agency tracking unemployment and inflation has withdrawn after withering criticism from across the political spectrum.  The White House says a new nominee will be named soon.",
#   'url': 'https://www.npr.org/2025/10/01/nx-s1-5559284/trumps-controversial-nominee-drops-bid-to-head-vital-data-gathering-agency',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/2000x1125+0+93/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F8a%2Fa6%2Fcf978ab04351bb0e2331e32ec36a%2F021025-bls-zayrharodriguez-6.jpg',
#   'publishedAt': '2025-10-01T16:34:16Z',
#   'content': "President Trump's nominee to lead the Bureau of Labor Statistics has withdrawn after widespread criticism that he was too partisan and inexperienced to hold such an important role in government. \r\nA … [+2166 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Jennifer Sor',
#   'title': "3 reasons the US can't count on wealthy Americans to keep the economy going strong",
#   'description': 'Wealthy Americans may not be able to power the economy with spending as much as some people think, BCA Research says.',
#   'url': 'https://www.businessinsider.com/recession-outlook-americans-wealthy-consumer-spending-stocks-job-market-2025-9',
#   'urlToImage': 'https://i.insider.com/68d6d583cc993f9955cf04fd?width=1200&format=jpeg',
#   'publishedAt': '2025-09-28T09:15:01Z',
#   'content': 'Mike Kemp/In Pictures via Getty Images\r\n<ul><li>The US may not be able to rely on rich Americans to power the economy, BCA Research said.</li><li>High-earning households have been a pillar of consume… [+3623 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': "Can Labour reverse 'desperate loss of faith' from business?",
#   'description': 'The government wants to keep the backing it won before the election, our business editor Simon Jack writes.',
#   'url': 'https://www.bbc.com/news/articles/cn0xyxnyz48o',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/7aa5/live/803f8e10-9af1-11f0-89b4-1b2d09c610c7.jpg',
#   'publishedAt': '2025-09-28T23:46:58Z',
#   'content': "Simon JackBusiness editor\r\nOne of the key audiences that the prime minister and the chancellor will have to convince at this year's Labour conference are the business leaders they targeted with a cha… [+6210 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Yahoo Finance Video',
#   'title': 'Big Tech earnings: The 3 things Wall Street will be listening for',
#   'description': 'Big Tech is on deck for earnings season this week with Magnificent Seven companies Meta Platforms (META), Microsoft (MSFT), and Alphabet (GOOGL, GOOG...',
# ...
#   'content': 'U.S. Health and Human Services Secretary Robert F. Kennedy Jr. is on a crusade that is hurting everyday Americans by driving chaos in our health system, disrupting and perhaps even threatening the re… [+7087 chars]'},
#  {'source': {'id': 'usa-today', 'name': 'USA Today'},
#   'author': 'Rex Huppke, USA TODAY',
#   'title': "If a humanitarian like Trump doesn't deserve the Nobel Peace Prize, who does? | Opinion",
#   'description': 'I’ll always remember where I was on Oct. 10, 2025, the day Donald J. Trump was viciously denied the Nobel Peace Prize.',
#   'url': 'https://www.usatoday.com/story/opinion/columnist/2025/10/10/trump-maria-machado-nobel-peace-prize-putin/86617345007/',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/i_6ulJH2MnPikEFBXzj.UA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA7Y2Y9d2VicA--/https://media.zenfs.com/en/usa_today_opinion_532/8b4f8f84a4486d213b1753632a476677',
#   'publishedAt': '2025-10-10T18:34:42Z',
#   'content': 'Ill always remember where I was on Oct. 10, 2025, the day Donald J. Trump was viciously denied the Nobel Peace Prize and the world stopped making sense.\r\nTrump had humbly and incessantly campaigned f… [+4929 chars]'},
#  {'source': {'id': 'usa-today', 'name': 'USA Today'},
#   'author': 'Rex Huppke, USA TODAY',
#   'title': "ICE shot a praying pastor with pepper balls. Top Republican says it's fine. | Opinion",
#   'description': 'Let it be known that Republican House Speaker Mike Johnson has no problem with ICE agents shooting a pastor in the head with pepper balls.',
#   'url': 'https://www.usatoday.com/story/opinion/columnist/2025/10/15/ice-chicago-mike-johnson-violence/86694002007/',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/SclSTHadAgm1FFV__TLUOA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA7Y2Y9d2VicA--/https://media.zenfs.com/en/usa_today_opinion_532/574a22b75a2e14b4e47c01ed44a706d0',
#   'publishedAt': '2025-10-15T16:35:26Z',
#   'content': 'CHICAGO Let it be known far and wide that Republican House Speaker Mike Johnson, who has called himself a Bible-believing Christian, has no problem whatsoever with Immigration and Customs Enforcement… [+5453 chars]'},
#  {'source': {'id': 'the-hill', 'name': 'The Hill'},
#   'author': 'Becket Adams, opinion contributor',
#   'title': 'Opinion - Surprise — NPR never really needed all that taxpayer money in the first place!',
#   'description': 'In July, National Public Radio’s CEO cried and hollered, claiming her organization could not possibly survive without government funding. This week, however,...',
#   'url': 'https://thehill.com/opinion/campaign/5537336-surprise-npr-never-really-needed-taxpayer-funding-in-the-first-place/',
#   'urlToImage': 'https://media.zenfs.com/en/the_hill_articles_341/aab7368b5db1961322e975e34c34f3cf',
#   'publishedAt': '2025-10-06T11:00:00Z',
#   'content': 'In July, National Public Radios CEO cried and hollered, claiming her organization could not possibly survive without government funding.\r\nThis week, however, the same news organization claimed that o… [+4411 chars]'},
#  {'source': {'id': 'the-hill', 'name': 'The Hill'},
#   'author': 'John Mac Ghlionn, opinion contributor',
#   'title': 'Opinion - Why men are leaving the left — and not coming back',
#   'description': 'The Democratic Party is losing men due to its lack of authenticity, as its attempts to woo them with branding and beer ads have failed to resonate with them,...',
#   'url': 'https://thehill.com/opinion/campaign/5561387-democratic-party-losing-men/',
#   'urlToImage': 'https://media.zenfs.com/en/the_hill_articles_341/ad55ec165a1ddcb64fd0d79f6764698c',
#   'publishedAt': '2025-10-19T16:00:00Z',
#   'content': 'The Democratic Party is hemorrhaging men. Across the U.S., they are leaving in waves from the unions that once powered the partys muscle, from classrooms that once echoed with idealism, and from a mo… [+5331 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Sean Hollister',
#   'title': 'Intel’s tick-tock isn’t coming back, and everything else I just learned',
#   'description': 'With Windows 10 on its last legs, Intel is looking forward to the PC industry growing more than it has in years - the most since 2021, when the covid-19 pandemic revived the industry by creating a huge surge in demand. But it seems the struggling Intel, which…',
#   'url': 'https://www.theverge.com/tech/805652/intel-q3-2025-earnings-18a-panther-lake-ai-gpus-annual',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/25007293/intel14900k.jpg?quality=90&strip=all&crop=0%2C10.462709848801%2C100%2C79.074580302398&w=1200',
#   'publishedAt': '2025-10-23T23:18:48Z',
#   'content': '<ul><li></li><li></li><li></li></ul>\r\nIntels Q3 earnings call had some intriguing insight.\r\nIntels Q3 earnings call had some intriguing insight.\r\nby\r\nSean HollisterClose\r\nSean Hollister\r\nPosts from t… [+4319 chars]'},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': None,
#   'title': 'Why Are Survivors Quitting The Grooming Gangs Inquiry?',
#   'description': 'The government is facing questions over it’s handing of an inquiry into grooming gangs.',
#   'url': 'https://www.bbc.co.uk/sounds/play/p0mb5t6y',
#   'urlToImage': 'https://ichef.bbci.co.uk/images/ic/1024x576/p0l7jnbt.jpg',
#   'publishedAt': '2025-10-22T19:27:00Z',
#   'content': 'Available for over a year\r\nToday, concerns are growing over the governments handling of the set up of a national inquiry into grooming gangs. Two potential candidates to chair the inquiry have withdr… [+1270 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'lvaranasi@businessinsider.com (Lakshmi Varanasi)',
#   'title': "Sequoia partner says there's too much venture capital and not enough companies to invest in: 'It's a return-free risk'",
#   'description': "Sequoia Capital partner and former PayPal exec, Roelof Botha, says the numbers in the venture capital game don't make sense.",
#   'url': 'https://www.businessinsider.com/sequoia-roelof-botha-venture-capital-return-free-risk-2025-10',
#   'urlToImage': 'https://i.insider.com/68eff7cfcc993f9955d04473?width=1200&format=jpeg',
#   'publishedAt': '2025-10-16T09:20:02Z',
#   'content': "Even a veteran Silicon Valley investor can't make the numbers behind venture capital add up.\r\nSequoia Capital partner and former PayPal exec, Roelof Botha, appeared on two podcasts over the past week… [+1882 chars]"},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': "'We want to raise our children': Life in Gaza after hostages and prisoners released",
#   'description': 'The United Nations Development Programme (UNDP) says over 80% of all buildings in the territory are destroyed or damaged.',
#   'url': 'https://www.bbc.com/news/videos/cev1yyzve3ro',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/0b79/live/0001f880-a912-11f0-928c-71dbb8619e94.jpg',
#   'publishedAt': '2025-10-14T16:30:50Z',
#   'content': 'Trucks carrying aid were seen driving through a market in Khan Younis after Palestinian detainees and prisoners were reunited with their families as part of a ceasefire deal that started on Monday. \r… [+544 chars]'},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': None,
#   'title': 'Trump’s ‘CEO of everything’',
#   'description': 'Who is Larry Ellison, and what is his hold on America’s AI, attention and legacy media?',
#   'url': 'https://www.bbc.co.uk/sounds/play/w3ct71fs',
#   'urlToImage': 'https://ichef.bbci.co.uk/images/ic/raw/p0bwmc67.jpg',
#   'publishedAt': '2025-10-08T09:00:00Z',
#   'content': 'Available for over a year\r\nThe billionaire Larry Ellison could soon control huge portions of Americas AI, attention economy and legacy media. He already owns swathes of AI infrastructure and is prepa… [+553 chars]'},
#  {'source': {'id': 'espn', 'name': 'ESPN'},
#   'author': 'Ramona Shelburne and Kendra Andrews',
#   'title': "'Beyond repair': Napheesa Collier, Cathy Engelbert and a WNBA teetering on the brink",
#   'description': 'Amid the WNBA Finals, two of the most powerful people in the game are locked in a contentious battle -- for public opinion, power and money.',
#   'url': 'https://www.espn.com/wnba/story/_/id/46501777/beyond-repair-napheesa-collier-cathy-engelbert-wnba-teetering-brink',
#   'urlToImage': 'https://a3.espncdn.com/combiner/i?img=%2Fphoto%2F2025%2F1006%2Fr1556442_1296x729_16%2D9.jpg',
#   'publishedAt': '2025-10-06T13:24:22Z',
#   'content': 'NAPHEESA COLLIER BARELY slept the night before she wrote the statement that would rock the WNBA.\r\nIt was late in the evening on Friday, Sept. 26, only a few hours after the Minnesota Lynx dropped Gam… [+14814 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Jing Pan',
#   'title': 'Robert Kiyosaki warns US baby boomers will be ‘wiped out,’ left homeless ‘all over’ the country — how to fight back now',
#   'description': 'Will your parents be “on the street” soon?',
#   'url': 'https://finance.yahoo.com/news/robert-kiyosaki-warns-us-baby-111500504.html',
#   'urlToImage': 'https://media.zenfs.com/en/moneywise_ecomm_711/f35bf6bc644e46030feb86f05f615e6a',
#   'publishedAt': '2025-10-17T11:15:00Z',
#   'content': 'Wikimedia Commons\r\nMoneywise and Yahoo Finance LLC may earn commission or revenue through links in the content below.\r\nAmericas baby boomers are often seen as the lucky ones the generation that bough… [+7060 chars]'},
#  {'source': {'id': None, 'name': 'Kotaku'},
#   'author': 'Claire Jackson',
#   'title': 'Counter Strike 2 Update Is A $2 Billion Shock To The Skin Economy: ‘How Do I Explain This To The IRS?’',
#   'description': 'Might be time to hide some skins under your digital mattress\nThe post Counter Strike 2 Update Is A $2 Billion Shock To The Skin Economy: ‘How Do I Explain This To The IRS?’ appeared first on Kotaku.',
#   'url': 'https://kotaku.com/counter-strike-2-cs2-valve-skin-marketplace-covert-red-2000638560',
#   'urlToImage': 'https://kotaku.com/app/uploads/2025/10/to-the-mooon-1200x675.jpg',
#   'publishedAt': '2025-10-23T14:59:51Z',
#   'content': 'If you play Counter-Strike 2 and enjoy trading skins for financial gain, youre either real happy right now or, um, quite the opposite. Valve recently pushed an update to the games controversial marke… [+1680 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'msmash',
#   'title': "'America's Elite Universities Have Lost Their Way'",
#   'description': "Trust in America's elite universities has declined sharply over the past decade [non-paywalled source]. A Manhattan Institute survey conducted in June 2025 found that only 42% of Americans have significant trust in higher education, down 15 percentage points …",
#   'url': 'https://news.slashdot.org/story/25/09/30/146247/americas-elite-universities-have-lost-their-way',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/usa_64.png',
#   'publishedAt': '2025-09-30T14:06:00Z',
#   'content': 'Our colleges are too expensive to go to meanwhile our conservatives have spent decades demonizing them as places where kids get brainwashed into thinking that LGBTQ people should be respected just li… [+314 chars]'},
#  {'source': {'id': None, 'name': 'Barchart.com'},
#   'author': 'Jabran Kundi',
#   'title': 'Dear Intel Stock Fans, Mark Your Calendars for October 23',
#   'description': "The upcoming earnings could bring a positive surprise, but everyone has their eyes on the company's product roadmap.",
#   'url': 'https://www.barchart.com/story/news/35588511/dear-intel-stock-fans-mark-your-calendars-for-october-23',
#   'urlToImage': 'https://media.zenfs.com/en/barchart_com_477/4bc6cedfb85e4ad436b4816e4ecab9b9',
#   'publishedAt': '2025-10-21T15:43:43Z',
#   'content': 'Intel (INTC) is expected to announce its Q3 earnings report later this week, and unlike the last few times, there is visibly more optimism among investors. It is not difficult to figure out why. The … [+5348 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Aniruddha Ganguly',
#   'title': "Buy, Sell or Hold GOOGL Stock Before Q3 Earnings? Here's What to Know",
#   'description': "Alphabet's AI-driven Search gains, cloud expansion, and easing regulatory pressure set the stage for its Q3 2025 earnings release.",
#   'url': 'https://finance.yahoo.com/news/buy-sell-hold-googl-stock-173800424.html',
#   'urlToImage': 'https://media.zenfs.com/en/zacks.com/30e90ac213ebedcfe9ef1b79c529169c',
#   'publishedAt': '2025-10-24T17:38:00Z',
#   'content': 'Alphabet GOOGL is set to report third-quarter 2025 results on Oct. 30.\xa0\r\nFor third-quarter 2025, the Zacks Consensus Estimate for earnings is pegged at $2.27 per share, down 3 cents over the past 30 … [+6017 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Callie Cox',
#   'title': "The optimistic millennials' guide to Gen Z's career apocalypse",
#   'description': "I'm a millennial who graduated during the financial crisis. Here's what Gen Z should know about a tough job market.",
#   'url': 'https://www.businessinsider.com/millennials-guide-gen-z-job-struggles-career-apocalypse-recession-hiring2025-10',
#   'urlToImage': 'https://i.insider.com/68fa8a61c007ca8c273787fd?width=1200&format=jpeg',
#   'publishedAt': '2025-10-27T08:34:01Z',
#   'content': 'Imagine this: Just as a new generation enters the job market, a crisis rocks the world and permanently alters the economic landscape, forcing the young people starting out on their career journeys to… [+11174 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Lucas Ropek',
#   'title': 'CNN Is Trying to Sell a Streaming Service Again (Only More Expensive This Time)',
#   'description': 'Giving the Quibi of news one more try.',
#   'url': 'https://gizmodo.com/cnn-is-trying-to-sell-a-streaming-service-again-only-more-expensive-this-time-2000673714',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2022/10/d19f64db91ad92c656d503ffb2819206.jpg',
#   'publishedAt': '2025-10-17T21:25:32Z',
#   'content': 'For years now, CNN has been haplessly trying to modernize its media franchise by launching a streaming service. Those of you aware of these efforts will recall CNN+, which launched a few years ago an… [+2457 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'EditorDavid',
#   'title': 'Three-Wheeled Solar Car Maker Aptera is About to Go Public',
#   'description': 'Last November Aptera successfully tested its first production-intent three-wheel solar-powered EV — and said it already had over 50,000 reservations. The vehicles had a solar charge range of 40 miles per day, reported Digital Trends, noting the crowdfunded co…',
#   'url': 'https://tech.slashdot.org/story/25/10/12/0237231/three-wheeled-solar-car-maker-aptera-is-about-to-go-public',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/transportation_64.png',
#   'publishedAt': '2025-10-12T16:34:00Z',
#   'content': 'Last November Aptera successfully tested its first production-intent three-wheel solar-powered EV — and said it already had over 50,000 reservations. The vehicles had a solar charge range of 40 miles… [+1848 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Bloomberg',
#   'title': 'Elon Musk Pitches $1 Trillion Pay Package on Tesla Earnings Call',
#   'description': "Elon Musk, the world's richest person, spent the end of Tesla Inc.'s earnings call pleading with investors to approve his $1 trillion pay package and...",
#   'url': 'https://finance.yahoo.com/video/elon-musk-pitches-1-trillion-134941503.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/aRKAARxhEk8ntL5beJy6qw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://media.zenfs.com/en/bloomberg_markets_video_2/3e56de3515be4c98c8ff03fb6b18ce3a',
#   'publishedAt': '2025-10-23T13:49:41Z',
#   'content': "Elon Musk, the world's richest person, spent the end of Tesla Inc.'s earnings call pleading with investors to approve his $1 trillion pay package and blasting the shareholder advisory firms that have… [+30 chars]"}]

# %%
def classify_article(title,description):
    macro_keywords=["inflation", "interest rates", "GDP", "monetary", "fiscal"]
    company_keywords = ["IPO", "earnings", "merger", "company", "revenue"]
    oped_keywords = ["opinion", "editorial", "analysis", "column"]

    text=f"{title} {description}".lower()
    if any(word in text for word in macro_keywords):
        return "Macro Economics"
    elif any(word in text for word in company_keywords):
        return "Company / Industry"
    elif any(word in text for word in oped_keywords):
        return "Op-Ed"
    else:
        return "Other"

# %%
title="UK will be second-fastest-growing G7 economy, IMF predicts"
description='The International Monetary Fund (IMF) has upgraded the rate at which the UK economy will grow this year.'
classify_article(title=title,description=description)
# Out:
# 'Macro Economics'

# %%
import sqlite3

DB_PATH=r"database/article.db"
os.makedirs("database",exist_ok=True)
def init_db():
    conn= sqlite3.connect(DB_PATH)
    cur=conn.cursor()
    cur.execute("""
        CREATE TABLE IF NOT EXISTS read_articles (
                title TEXT,
                url TEXT,
                category TEXT,
                date TIMESTAMP DEFAULT CURRENT_TIMESTAMP
                )
        """)
    conn.commit()
    conn.close()

def article_exists(url):
    conn=sqlite3.connect(DB_PATH)
    cur=conn.cursor()
    cur.execute("SELECT 1 FROM read_articles WHERE url = ?", (url,))
    exists=cur.fetchone() is not None
    conn.close()
    return exists

def log_article(title, url, category):
    conn=sqlite3.connect(DB_PATH)
    cur=conn.cursor()
    cur.execute("INSERT INTO read_articles (title, url, category) VALUES (?,?,?)", (title, url, category))
    conn.commit()
    conn.close()

# %%
from groq import Groq
from langchain_groq import ChatGroq
import pandas as pd

client=Groq(api_key=os.getenv("GROQ_API_KEY"))
def llm_score(title, description,category):
    prompt = f"""
    You are an expert content filter.
    Rate from 1 to 10 how relevant this article is to the category: {category}.
    Respond ONLY with a number between 1 and 10.

    Title: {title}
    Description: {description}
    """

    response = client.chat.completions.create(
        model="qwen/qwen3-32b",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )
    output=response.choices[0].message.content.strip()
    score_match = re.search(r'\b([1-9]|10)\b', output)
    if score_match:
        return int(score_match.group())
    else:
        print(f" Unexpected response: {output}")
        return 0
    

def get_top_articles(articles):
  if not articles:
    return []
  df = pd.DataFrame(articles)

  best_articles = (
      df.sort_values("score", ascending=False)
        .groupby("category")
        .head(1)
        .reset_index(drop=True)
  )
  return best_articles.to_dict(orient="records")
    # return int(score_match.group()) if score_match else 0

# %%
def main():
    init_db()
    all_articles=[]
    
    articles=fetch_articles()
    new_articles = [a for a in articles if not article_exists(a.get("url", ""))]
    print(f"🆕 Found {len(new_articles)} new articles to process...")
    

    for article in new_articles:
        title=article.get("title","")
        description=article.get("description","")
        source=article.get("source",{}).get("name","")
        url=article.get("url","")

        category= classify_article(title, description )
        if category != "Other":
            score = llm_score(title, description, category)
            all_articles.append({
                "title": title,
                "description":description,
                "source":source,
                "url":url,
                "category":category,
                "score": score
            })
    top_articles=get_top_articles(all_articles)
    for a in top_articles:
        log_article(a["title"], a["url"],a["category"])

    send_email(top_articles)
    print("✅ Email sent with 3 top articles!")

# %%
import pandas as pd
def get_top_articles(articles):
  if not articles:
    return []
  df = pd.DataFrame(articles)

  best_articles = (
      df.sort_values("score", ascending=False)
        .groupby("category")
        .head(1)
        .reset_index(drop=True)
  )
  return top_articles.to_dict(orient="records")
  # print(best_articles[["category", "title", "source", "score", "url"]])
# Out:
#              category                                              title  \
# 0               Op-Ed  Opinion - Why men are leaving the left — and n...
# 1     Macro Economics    Inflation climbs to highest level since January
# 2  Company / Industry  Delta’s bet on wealthy Americans driving the e...
#
#                 source  score  \
# 0             The Hill     10
# 1             ABC News      9
# 2  Yahoo Entertainment      9
#
#                                                  url
# 0  https://thehill.com/opinion/campaign/5561387-d...
# 1  https://abcnews.go.com/Business/inflation-expe...
# 2  https://finance.yahoo.com/news/delta-bet-wealt...

# %%
best_articles.shape
# Out:
# (3, 6)

# %%
best_articles.head(3)
# Out:
#                                                title  \
# 0  Opinion - Why men are leaving the left — and n...
# 1    Inflation climbs to highest level since January
# 2  Delta’s bet on wealthy Americans driving the e...
#
#                                          description               source  \
# 0  The Democratic Party is losing men due to its ...             The Hill
# 1  A recent uptick in prices has coincided with a...             ABC News
# 2  Premium is on track to overtake main cabin in ...  Yahoo Entertainment
#
#                                                  url            category  \
# 0  https://thehill.com/opinion/campaign/5561387-d...               Op-Ed
# 1  https://abcnews.go.com/Business/inflation-expe...     Macro Economics
# 2  https://finance.yahoo.com/news/delta-bet-wealt...  Company / Industry
#
#    score
# 0     10
# 1      9
# 2      9

# %%
def send_email(top_articles):
    sender = os.getenv("EMAIL_USER")
    password = os.getenv("EMAIL_PASS")
    receiver = sender  # you can also change this to another recipient

    # Build email
    msg = MIMEMultipart("alternative")
    msg["Subject"] = "📰 Your Daily 3 Reads"
    msg["From"] = sender
    msg["To"] = receiver

    html_content = "<h3>Here are your 3 articles for today:</h3><ul>"
    for a in top_articles:
        html_content += f"<li><b>{a['category']}</b>: <a href='{a['url']}'>{a['title']}</a></li>"
    html_content += "</ul><br><p>Enjoy your reading! ☕</p>"

    msg.attach(MIMEText(html_content, "html"))

    # Connect securely to Gmail SMTP (SSL port 465)
    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
        server.login(sender, password)
        server.send_message(msg)
        print("✅ Email sent successfully!")
